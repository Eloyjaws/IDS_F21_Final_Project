# %%
import sys
sys.path.append("..")

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt

import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %%
df_3i = pd.read_csv("../data/3i-index-data.csv")
df_3i.head(4)
# Out:
#    Country Edition  1.1.1) Internet users  \
# 0  Algeria      E1                   31.9
# 1  Algeria      E2                   47.3
# 2  Algeria      E3                   54.2
# 3  Algeria      E4                   74.4
#
#    1.1.2) Fixed-line broadband subscribers  1.1.3) Mobile subscribers  \
# 0                                     5.71                      108.8
# 1                                     7.05                      116.0
# 2                                     7.76                      110.8
# 3                                     7.26                      111.7
#
#    1.1.4) Gender gap in internet access  \
# 0                                   NaN
# 1                                  22.0
# 2                                  11.7
# 3                                  21.7
#
#    1.1.5) Gender gap in mobile phone access  \
# 0                                       NaN
# 1                                       7.8
# 2                                       8.9
# 3                                       7.3
#
#    1.2.1) Average fixed broadband upload speed  \
# 0                                         1.69
# 1                                         6.12
# 2                                         2.59
# 3                                         1.97
#
#    1.2.2) Average fixed broadband download speed  \
# 0                                           3.39
# 1                                           7.85
# 2                                           3.77
# 3                                           3.87
#
#    1.2.3) Average fixed broadband latency  ...  \
# 0                                   74.00  ...
# 1                                   76.92  ...
# 2                                   64.71  ...
# 3                                   64.99  ...
#
#    BG15) Internet users (population)  BG16) Offline population  \
# 0                              15.23                     24.64
# 1                              17.44                     23.18
# 2                              19.71                     21.62
# 3                              20.64                     21.45
#
#    BG17) Internet access gender gap  BG18) Mobile phone access gender gap  \
# 0                               NaN                                   NaN
# 1                              13.0                                   7.0
# 2                               7.0                                   8.0
# 3                              13.0                                   6.0
#
#    BG19) Internet users (percent of population)  BG20) Male internet users  \
# 0                                          38.2                        NaN
# 1                                          42.9                       59.0
# 2                                          47.7                       60.0
# 3                                          49.0                       60.0
#
#    BG21) Female internet users  BG22) Male mobile phone subscribers  \
# 0                          NaN                                 95.5
# 1                         46.0                                 90.0
# 2                         53.0                                 90.0
# 3                         47.0                                 82.0
#
#    BG23) Female mobile phone subscribers  \
# 0                                   89.9
# 1                                   83.0
# 2                                   82.0
# 3                                   76.0
#
#    BG24) Total fixed line broadband subscribers
# 0                                       2269348
# 1                                       2859567
# 2                                       3210267
# 3                                       3067022
#
# [4 rows x 86 columns]

# %%
df_3i.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 86 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Country                                                             600 non-null    object
#  1   Edition                                                             600 non-null    object
#  2   1.1.1) Internet users                                               600 non-null    float64
#  3   1.1.2) Fixed-line broadband subscribers                             600 non-null    float64
#  4   1.1.3) Mobile subscribers                                           600 non-null    float64
#  5   1.1.4) Gender gap in internet access                                480 non-null    float64
#  6   1.1.5) Gender gap in mobile phone access                            480 non-null    float64
#  7   1.2.1) Average fixed broadband upload speed                         600 non-null    float64
#  8   1.2.2) Average fixed broadband download speed                       600 non-null    float64
#  9   1.2.3) Average fixed broadband latency                              600 non-null    float64
#  10  1.2.4) Average mobile upload speed                                  600 non-null    float64
#  11  1.2.5) Average mobile download speed                                600 non-null    float64
#  12  1.2.6) Average mobile latency                                       600 non-null    float64
#  13  1.2.7) Bandwidth capacity                                           598 non-null    float64
#  14  1.3.1) Network coverage (min. 2G)                                   600 non-null    float64
#  15  1.3.2) Network coverage (min. 3G)                                   600 non-null    float64
#  16  1.3.3) Network coverage (min. 4G)                                   600 non-null    float64
#  17  1.3.4) 5G deployment                                                240 non-null    float64
#  18  1.3.5) Government initiatives to make Wi-Fi available               501 non-null    float64
#  19  1.3.6) Private sector initiatives to make Wi-Fi available           501 non-null    float64
#  20  1.3.7) Unlicensed spectrum policy                                   429 non-null    float64
#  21  1.3.8) Internet exchange points                                     600 non-null    float64
#  22  1.4.1) Urban electricity access                                     600 non-null    float64
#  23  1.4.2) Rural electricity access                                     600 non-null    float64
#  24  2.1.1) Smartphone cost (handset)                                    600 non-null    float64
#  25  2.1.2) Mobile phone cost (prepaid tariff)                           600 non-null    float64
#  26  2.1.3) Mobile phone cost (postpaid tariff)                          600 non-null    float64
#  27  2.1.4) Fixed-line monthly broadband cost                            600 non-null    float64
#  28  2.2.1) Average revenue per user (ARPU, annualized)                  600 non-null    float64
#  29  2.2.2) Wireless operators' market share                             600 non-null    int64
#  30  2.2.3) Broadband operators' market share                            600 non-null    int64
#  31  3.1.1) Availability of local news in local languages                501 non-null    float64
#  32  3.1.2) Concentration of websites using country-level domains        501 non-null    float64
#  33  3.1.3) Availability of e-Government services in the local language  501 non-null    float64
#  34  3.2.1) e-Finance content                                            501 non-null    float64
#  35  3.2.2) Value of e-finance                                           429 non-null    float64
#  36  3.2.3) e-Health content                                             501 non-null    float64
#  37  3.2.4) Value of e-health                                            429 non-null    float64
#  38  3.2.5) e-Entertainment usage                                        429 non-null    float64
#  39  3.2.6) e-Commerce content                                           600 non-null    float64
#  40  3.2.7) Value of e-Commerce                                          429 non-null    float64
#  41  3.2.8) Open data policies                                           240 non-null    float64
#  42  4.1.1) Level of literacy                                            600 non-null    float64
#  43  4.1.2) Educational attainment                                       600 non-null    float64
#  44  4.1.3) Support for digital literacy                                 501 non-null    float64
#  45  4.1.4) Level of web accessibility                                   503 non-null    float64
#  46  4.2.1) Privacy regulations                                          501 non-null    float64
#  47  4.2.2) Trust in online privacy                                      429 non-null    float64
#  48  4.2.3) Trust in Government websites and apps                        429 non-null    float64
#  49  4.2.4) Trust in Non-government websites and apps                    429 non-null    float64
#  50  4.2.5) Trust in information from social media                       429 non-null    float64
#  51  4.2.6) e-Commerce safety                                            429 non-null    float64
#  52  4.3.1) National female e-inclusion policies                         429 non-null    float64
#  53  4.3.1.1) Comprehensive female e-inclusion plan                      429 non-null    float64
#  54  4.3.1.2) Female digital skills training plan                        429 non-null    float64
#  55  4.3.1.3) Female STEM education plan                                 429 non-null    float64
#  56  4.3.2) Government e-inclusion strategy                              501 non-null    float64
#  57  4.3.3) National broadband strategy                                  501 non-null    float64
#  58  4.3.4) Funding for broadband buildout                               501 non-null    float64
#  59  4.3.5) Technology-neutrality policy for spectrum use                429 non-null    float64
#  60  4.3.6) National digital identification system                       600 non-null    int64
#  61  4.3.7) Government efforts to promote 5G                             240 non-null    float64
#  62  BG1) Nominal GDP                                                    600 non-null    float64
#  63  BG2) Population                                                     600 non-null    float64
#  64  BG3) Urban population                                               600 non-null    float64
#  65  BG4) GNI per capita                                                 600 non-null    int64
#  66  BG5) GINI coefficient                                               600 non-null    float64
#  67  BG6) Population under the poverty line                              600 non-null    float64
#  68  BG7) Total electricity access                                       600 non-null    float64
#  69  BG8) Cable landing stations                                         600 non-null    float64
#  70  BG9) Percentage of schools with Internet access                     600 non-null    float64
#  71  BG10) Global Peace Index                                            600 non-null    float64
#  72  BG11) Democracy Index                                               600 non-null    float64
#  73  BG12) Corruption Perceptions Index                                  600 non-null    int64
#  74  BG13) EIU Business Environment Rankings                             600 non-null    float64
#  75  BG14) UN E-Government Development Index                             600 non-null    float64
#  76  BG15) Internet users (population)                                   600 non-null    float64
#  77  BG16) Offline population                                            600 non-null    float64
#  78  BG17) Internet access gender gap                                    480 non-null    float64
#  79  BG18) Mobile phone access gender gap                                480 non-null    float64
#  80  BG19) Internet users (percent of population)                        600 non-null    float64
#  81  BG20) Male internet users                                           480 non-null    float64
#  82  BG21) Female internet users                                         480 non-null    float64
#  83  BG22) Male mobile phone subscribers                                 600 non-null    float64
#  84  BG23) Female mobile phone subscribers                               600 non-null    float64
#  85  BG24) Total fixed line broadband subscribers                        600 non-null    int64
# dtypes: float64(78), int64(6), object(2)
# memory usage: 403.2+ KB

# %%
df_3i_corrected = df_3i.iloc[:, [0, 1, 3, 4, 5, 6, 12, 13, 21, 22, 23, 24, 28, 38, 62, 63, 64, 65, 66, 67, 68, 70, 71, 72, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85]]
df_3i_corrected.columns = [x.split(') ')[-1] for x in df_3i_corrected.columns]
df_3i_corrected
# Out:
#       Country Edition  Fixed-line broadband subscribers  Mobile subscribers  \
# 0     Algeria      E1                              5.71               108.8
# 1     Algeria      E2                              7.05               116.0
# 2     Algeria      E3                              7.76               110.8
# 3     Algeria      E4                              7.26               111.7
# 4     Algeria      E5                              8.32               109.4
# ..        ...     ...                               ...                 ...
# 595  Zimbabwe      E1                              1.19                92.3
# 596  Zimbabwe      E2                              1.22                91.8
# 597  Zimbabwe      E3                              1.32                99.0
# 598  Zimbabwe      E4                              1.41                89.4
# 599  Zimbabwe      E5                              1.40                90.1
#
#      Gender gap in internet access  Gender gap in mobile phone access  \
# 0                              NaN                                NaN
# 1                             22.0                                7.8
# 2                             11.7                                8.9
# 3                             21.7                                7.3
# 4                             10.9                                8.0
# ..                             ...                                ...
# 595                            NaN                                NaN
# 596                           32.4                                1.2
# 597                           45.2                                2.5
# 598                           26.3                               -2.7
# 599                           13.2                               -3.7
#
#      Average mobile latency  Bandwidth capacity  Internet exchange points  \
# 0                    143.00             30806.0                      0.00
# 1                     83.98             31440.0                      0.00
# 2                     70.21             25307.0                      0.00
# 3                     72.89             20944.0                      0.00
# 4                     59.15             20944.0                      0.00
# ..                      ...                 ...                       ...
# 595                   93.00              4999.0                      0.00
# 596                   66.20             10064.0                      0.00
# 597                   50.00             12376.0                      0.60
# 598                   47.62             12376.0                      0.69
# 599                   47.29             12376.0                      0.68
#
#      Urban electricity access  ...  Internet users (population)  \
# 0                       100.0  ...                        15.23
# 1                       100.0  ...                        17.44
# 2                       100.0  ...                        19.71
# 3                       100.0  ...                        20.64
# 4                       100.0  ...                        20.64
# ..                        ...  ...                          ...
# 595                      80.0  ...                         3.14
# 596                      81.2  ...                         3.24
# 597                      81.2  ...                         3.85
# 598                      81.6  ...                         3.85
# 599                      88.8  ...                         3.85
#
#      Offline population  Internet access gender gap  \
# 0                 24.64                         NaN
# 1                 23.18                        13.0
# 2                 21.62                         7.0
# 3                 21.45                        13.0
# 4                 21.45                         7.0
# ..                  ...                         ...
# 595               10.67                         NaN
# 596               10.79                        12.0
# 597               10.39                        19.0
# 598               10.39                        10.0
# 599               10.39                         5.0
#
#      Mobile phone access gender gap  Internet users (percent of population)  \
# 0                               NaN                                    38.2
# 1                               7.0                                    42.9
# 2                               8.0                                    47.7
# 3                               6.0                                    49.0
# 4                               7.0                                    49.0
# ..                              ...                                     ...
# 595                             NaN                                    22.7
# 596                             1.0                                    23.1
# 597                             2.0                                    27.1
# 598                            -2.0                                    27.1
# 599                            -3.0                                    27.1
#
#      Male internet users  Female internet users  \
# 0                    NaN                    NaN
# 1                   59.0                   46.0
# 2                   60.0                   53.0
# 3                   60.0                   47.0
# 4                   64.0                   57.0
# ..                   ...                    ...
# 595                  NaN                    NaN
# 596                 37.0                   25.0
# 597                 42.0                   23.0
# 598                 38.0                   28.0
# 599                 38.0                   33.0
#
#      Male mobile phone subscribers  Female mobile phone subscribers  \
# 0                             95.5                             89.9
# 1                             90.0                             83.0
# 2                             90.0                             82.0
# 3                             82.0                             76.0
# 4                             87.0                             80.0
# ..                             ...                              ...
# 595                           75.0                             68.0
# 596                           81.0                             80.0
# 597                           80.0                             78.0
# 598                           75.0                             77.0
# 599                           80.0                             83.0
#
#      Total fixed line broadband subscribers
# 0                                   2269348
# 1                                   2859567
# 2                                   3210267
# 3                                   3067022
# 4                                   3582739
# ..                                      ...
# 595                                  163987
# 596                                  170838
# 597                                  187310
# 598                                  203056
# 599                                  204424
#
# [600 rows x 34 columns]

# %%
df_3i_corrected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 34 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Country                                      600 non-null    object
#  1   Edition                                      600 non-null    object
#  2   Fixed-line broadband subscribers             600 non-null    float64
#  3   Mobile subscribers                           600 non-null    float64
#  4   Gender gap in internet access                480 non-null    float64
#  5   Gender gap in mobile phone access            480 non-null    float64
#  6   Average mobile latency                       600 non-null    float64
#  7   Bandwidth capacity                           598 non-null    float64
#  8   Internet exchange points                     600 non-null    float64
#  9   Urban electricity access                     600 non-null    float64
#  10  Rural electricity access                     600 non-null    float64
#  11  Smartphone cost (handset)                    600 non-null    float64
#  12  Average revenue per user (ARPU, annualized)  600 non-null    float64
#  13  e-Entertainment usage                        429 non-null    float64
#  14  Nominal GDP                                  600 non-null    float64
#  15  Population                                   600 non-null    float64
#  16  Urban population                             600 non-null    float64
#  17  GNI per capita                               600 non-null    int64
#  18  GINI coefficient                             600 non-null    float64
#  19  Population under the poverty line            600 non-null    float64
#  20  Total electricity access                     600 non-null    float64
#  21  Percentage of schools with Internet access   600 non-null    float64
#  22  Global Peace Index                           600 non-null    float64
#  23  Democracy Index                              600 non-null    float64
#  24  Internet users (population)                  600 non-null    float64
#  25  Offline population                           600 non-null    float64
#  26  Internet access gender gap                   480 non-null    float64
#  27  Mobile phone access gender gap               480 non-null    float64
#  28  Internet users (percent of population)       600 non-null    float64
#  29  Male internet users                          480 non-null    float64
#  30  Female internet users                        480 non-null    float64
#  31  Male mobile phone subscribers                600 non-null    float64
#  32  Female mobile phone subscribers              600 non-null    float64
#  33  Total fixed line broadband subscribers       600 non-null    int64
# dtypes: float64(30), int64(2), object(2)
# memory usage: 159.5+ KB

# %%
pd.options.mode.chained_assignment = None  # default='warn'

edition_to_year = {
    'E1': 2017,
    'E2': 2018,
    'E3': 2019,
    'E4': 2020,
    'E5': 2021
}

def get_year(edition):
    return edition.apply(lambda edition: edition_to_year[edition])

df_3i_corrected['Year'] = get_year(df_3i_corrected['Edition'])

df_3i_corrected[['Country', 'Year', 'Edition', 'Internet users (percent of population)', 'Internet users (population)', 'Population', 'Offline population']].query("Country == 'United States'")
# Out:
#            Country  Year Edition  Internet users (percent of population)  \
# 565  United States  2017      E1                                    74.6
# 566  United States  2018      E2                                    85.5
# 567  United States  2019      E3                                    87.3
# 568  United States  2020      E4                                    88.5
# 569  United States  2021      E5                                    88.5
#
#      Internet users (population)  Population  Offline population
# 565                       239.23       323.0               81.65
# 566                       276.32       325.1               46.69
# 567                       283.72       327.1               41.37
# 568                       289.48       329.1               37.62
# 569                       289.48       331.0               37.62

# %%
df_3i_2021 = df_3i_corrected.query("Year == 2021")
df_3i_population_2021 = df_3i_2021[["Country", "Year", 'Internet users (population)', 'Internet users (percent of population)', 'Population', 'Offline population']]
df_3i_population_2021
# Out:
#         Country  Year  Internet users (population)  \
# 4       Algeria  2021                        20.64
# 9        Angola  2021                         4.28
# 14    Argentina  2021                        32.65
# 19    Australia  2021                        21.28
# 24      Austria  2021                         7.59
# ..          ...   ...                          ...
# 579  Uzbekistan  2021                        17.93
# 584   Venezuela  2021                        20.08
# 589     Vietnam  2021                        66.27
# 594      Zambia  2021                         2.48
# 599    Zimbabwe  2021                         3.85
#
#      Internet users (percent of population)  Population  Offline population
# 4                                      49.0        43.7               21.45
# 9                                      14.3        32.9               25.54
# 14                                     74.3        45.2               11.29
# 19                                     86.5        25.5                3.31
# 24                                     87.8         8.7                1.06
# ..                                      ...         ...                 ...
# 579                                    55.2        33.5               14.55
# 584                                    64.3        28.0               11.14
# 589                                    68.7        97.3               30.19
# 594                                    14.3        18.4               14.87
# 599                                    27.1        14.9               10.39
#
# [120 rows x 6 columns]

# %%
df_3i_ip_2021 = df_3i_2021.query('Year == 2021')
df_3i_ip_2021
# Out:
#         Country Edition  Fixed-line broadband subscribers  Mobile subscribers  \
# 4       Algeria      E5                              8.32               109.4
# 9        Angola      E5                              0.37                46.6
# 14    Argentina      E5                             19.64               125.8
# 19    Australia      E5                             34.73               110.6
# 24      Austria      E5                             28.13               119.8
# ..          ...     ...                               ...                 ...
# 579  Uzbekistan      E5                             13.94               101.2
# 584   Venezuela      E5                              8.98                47.3
# 589     Vietnam      E5                             15.35               141.2
# 594      Zambia      E5                              0.50                96.4
# 599    Zimbabwe      E5                              1.40                90.1
#
#      Gender gap in internet access  Gender gap in mobile phone access  \
# 4                             10.9                                8.0
# 9                             30.6                               14.4
# 14                            -2.6                               -2.4
# 19                             2.1                                2.2
# 24                             2.2                               -1.0
# ..                             ...                                ...
# 579                           15.1                               15.9
# 584                          -16.4                              -14.1
# 589                           13.6                                4.2
# 594                           27.8                               13.9
# 599                           13.2                               -3.7
#
#      Average mobile latency  Bandwidth capacity  Internet exchange points  \
# 4                     59.15             20944.0                      0.00
# 9                     55.03             11693.0                      0.63
# 14                    40.78             42275.0                      6.03
# 19                    30.52             67209.0                      9.52
# 24                    28.22             52219.0                     10.41
# ..                      ...                 ...                       ...
# 579                   53.48             25606.0                      0.30
# 584                   72.49             20977.0                      0.00
# 589                   27.48            120708.0                      0.10
# 594                   52.91             14746.0                      0.00
# 599                   47.29             12376.0                      0.68
#
#      Urban electricity access  ...  Offline population  \
# 4                       100.0  ...               21.45
# 9                        61.0  ...               25.54
# 14                      100.0  ...               11.29
# 19                      100.0  ...                3.31
# 24                      100.0  ...                1.06
# ..                        ...  ...                 ...
# 579                     100.0  ...               14.55
# 584                     100.0  ...               11.14
# 589                     100.0  ...               30.19
# 594                      76.3  ...               14.87
# 599                      88.8  ...               10.39
#
#      Internet access gender gap  Mobile phone access gender gap  \
# 4                           7.0                             7.0
# 9                          10.5                            10.1
# 14                         -2.0                            -2.0
# 19                          2.0                             2.0
# 24                          2.0                            -1.0
# ..                          ...                             ...
# 579                         8.0                            14.0
# 584                        -9.0                            -9.0
# 589                         9.0                             4.0
# 594                        10.0                            10.0
# 599                         5.0                            -3.0
#
#      Internet users (percent of population)  Male internet users  \
# 4                                      49.0                 64.0
# 9                                      14.3                 37.3
# 14                                     74.3                 77.0
# 19                                     86.5                 94.0
# 24                                     87.8                 91.0
# ..                                      ...                  ...
# 579                                    55.2                 53.0
# 584                                    64.3                 55.0
# 589                                    68.7                 66.0
# 594                                    14.3                 36.0
# 599                                    27.1                 38.0
#
#      Female internet users  Male mobile phone subscribers  \
# 4                     57.0                           87.0
# 9                     26.9                           75.1
# 14                    79.0                           83.0
# 19                    92.0                           93.0
# 24                    89.0                           96.0
# ..                     ...                            ...
# 579                   45.0                           88.0
# 584                   64.0                           64.0
# 589                   57.0                           95.0
# 594                   26.0                           72.0
# 599                   33.0                           80.0
#
#      Female mobile phone subscribers  Total fixed line broadband subscribers  \
# 4                               80.0                                 3582739
# 9                               65.0                                  119047
# 14                              85.0                                 8793181
# 19                              91.0                                 8705523
# 24                              97.0                                 2513000
# ..                               ...                                     ...
# 579                             74.0                                 4597265
# 584                             73.0                                 2561210
# 589                             91.0                                14802380
# 594                             62.0                                   88891
# 599                             83.0                                  204424
#
#      Year
# 4    2021
# 9    2021
# 14   2021
# 19   2021
# 24   2021
# ..    ...
# 579  2021
# 584  2021
# 589  2021
# 594  2021
# 599  2021
#
# [120 rows x 35 columns]

# %%
df_3i_ip_2021_sorted = df_3i_ip_2021.sort_values(by="Internet users (population)", ascending=False)

# %%
df_3i_corrected.query("Year == 2021")[['Year', 'Country', 'Internet users (population)']].nlargest(2, columns = ['Internet users (population)'])
# Out:
#      Year        Country  Internet users (population)
# 99   2021          China                       748.80
# 569  2021  United States                       289.48

# %%
df_3i_ip_2021_sorted = df_3i_ip_2021.sort_values(by="Internet users (population)", ascending=False)

fig = px.bar(
        df_3i_ip_2021_sorted, 
        x="Internet users (population)", 
        y="Country", 
        color="Country", 
        orientation='h',
        height=2800
        )

fig.show()
# Out:
# <div>                            <div id="20d484a1-7402-47ed-b462-eceafa7f3463" class="plotly-graph-div" style="height:2800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20d484a1-7402-47ed-b462-eceafa7f3463")) {                    Plotly.newPlot(                        "20d484a1-7402-47ed-b462-eceafa7f3463",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{y}<br>Internet users (population)=%{x}<extra></extra>","legendgroup":"China","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"China","offsetgroup":"China","orientation":"h","showlegend":true,"textposition":"auto","x":[748.8],"xaxis":"x","y":["China"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{y}<br>Internet users (population)=%{x}<extra></extra>","legendgroup":"United States","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"United States","offsetgroup":"United States","orientation":"h","showlegend":true,"textposition":"auto","x":[289.48],"xaxis":"x","y":["United States"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{y}<br>Internet users (population)=%{x}<extra></extra>","legendgroup":"India","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"h","showlegend":true,"textposition":"auto","x":[271.63],"xaxis":"x","y":["India"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{y}<br>Internet users (population)=%{x}<extra></extra>","legendgroup":"Brazil","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Brazil","offsetgroup":"Brazil","orientation":"h","showlegend":true,"textposition":"auto","x":[146.85],"xaxis":"x","y":["Brazil"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{y}<br>Internet users (population)=%{x}<extra></extra>","legendgroup":"Indonesia","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Indonesia","offsetgroup":"Indonesia","orientation":"h","showlegend":true,"textposition":"auto","x":[126.52],"xaxis":"x","y":["Indonesia"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{y}<br>Internet users (population)=%{x}<extra></extra>","legendgroup":"Russia","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Russia","offsetgroup":"Russia","orientation":"h","showlegend":true,"textposition":"auto","x":[123.06],"xaxis":"x","y":["Russia"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{y}<br>Internet users (population)=%{x}<extra></extra>","legendgroup":"Japan","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Japan","offsetgroup":"Japan","orientation":"h","showlegend":true,"textposition":"auto","x":[116.11],"xaxis":"x","y":["Japan"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{y}<br>Internet users (population)=%{x}<extra></extra>","legendgroup":"Mexico","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Mexico","offsetgroup":"Mexico","orientation":"h","showlegend":true,"textposition":"auto","x":[89.41],"xaxis":"x","y":["Mexico"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{y}<br>Internet users (population)=%{x}<extra></extra>","legendgroup":"Germany","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Germany","offsetgroup":"Germany","orientation":"h","showlegend":true,"textposition":"auto","x":[73.01],"xaxis":"x","y":["Germany"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{y}<br>Internet users (population)=%{x}<extra></extra>","legendgroup":"Vietnam","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Vietnam","offsetgroup":"Vietnam","orientation":"h","showlegend":true,"textposition":"auto","x":[66.27],"xaxis":"x","y":["Vietnam"],"yaxis":"y", ...

# %%
bars = (
    alt.Chart(df_3i_ip_2021_sorted.iloc[0:20, :])
    .mark_bar()
    .encode(
        alt.X('Country', sort=None),
        alt.Y('Internet users (population)'),
        tooltip=[],
        color='Country',
    )
)

plot_title = f"Internet users (in millions)"
bars.properties(title=plot_title)
# Out:
# alt.Chart(...)

# %%
bars = (
    alt.Chart(df_3i_corrected[["Country", "Offline population"]])
    .mark_bar()
    .encode(
        alt.X('Country', sort=None),
        alt.Y('Offline population', sort=None),
        tooltip=[],
        color='Country',
    )
)
plot_title = f"Offline population (in millions)"
bars.properties(title=plot_title)
# Out:
# alt.Chart(...)

# %%
fig = px.scatter(df_3i_corrected, x="Internet users (population)", y="Offline population", animation_frame="Year", animation_group="Country",
           size="Population", color="Country", hover_name="Country",
           log_x=False, size_max=55, title="Offline population (in millions)")
fig.show()
# Out:
# <div>                            <div id="d634e8d6-5632-4f2a-b6f2-360b460912ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d634e8d6-5632-4f2a-b6f2-360b460912ca")) {                    Plotly.newPlot(                        "d634e8d6-5632-4f2a-b6f2-360b460912ca",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Algeria<br>Year=2017<br>Internet users (population)=%{x}<br>Offline population=%{y}<br>Population=%{marker.size}<extra></extra>","hovertext":["Algeria"],"ids":["Algeria"],"legendgroup":"Algeria","marker":{"color":"#636efa","size":[40.6],"sizemode":"area","sizeref":0.46115702479338844,"symbol":"circle"},"mode":"markers","name":"Algeria","orientation":"v","showlegend":true,"x":[15.23],"xaxis":"x","y":[24.64],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Angola<br>Year=2017<br>Internet users (population)=%{x}<br>Offline population=%{y}<br>Population=%{marker.size}<extra></extra>","hovertext":["Angola"],"ids":["Angola"],"legendgroup":"Angola","marker":{"color":"#EF553B","size":[28.8],"sizemode":"area","sizeref":0.46115702479338844,"symbol":"circle"},"mode":"markers","name":"Angola","orientation":"v","showlegend":true,"x":[3.46],"xaxis":"x","y":[24.43],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Argentina<br>Year=2017<br>Internet users (population)=%{x}<br>Offline population=%{y}<br>Population=%{marker.size}<extra></extra>","hovertext":["Argentina"],"ids":["Argentina"],"legendgroup":"Argentina","marker":{"color":"#00cc96","size":[43.5],"sizemode":"area","sizeref":0.46115702479338844,"symbol":"circle"},"mode":"markers","name":"Argentina","orientation":"v","showlegend":true,"x":[29.31],"xaxis":"x","y":[13.77],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Australia<br>Year=2017<br>Internet users (population)=%{x}<br>Offline population=%{y}<br>Population=%{marker.size}<extra></extra>","hovertext":["Australia"],"ids":["Australia"],"legendgroup":"Australia","marker":{"color":"#ab63fa","size":[24.3],"sizemode":"area","sizeref":0.46115702479338844,"symbol":"circle"},"mode":"markers","name":"Australia","orientation":"v","showlegend":true,"x":[20.24],"xaxis":"x","y":[3.69],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Austria<br>Year=2017<br>Internet users (population)=%{x}<br>Offline population=%{y}<br>Population=%{marker.size}<extra></extra>","hovertext":["Austria"],"ids":["Austria"],"legendgroup":"Austria","marker":{"color":"#FFA15A","size":[8.6],"sizemode":"area","sizeref":0.46115702479338844,"symbol":"circle"},"mode":"markers","name":"Austria","orientation":"v","showlegend":true,"x":[7.18],"xaxis":"x","y":[1.37],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Azerbaijan<br>Year=2017<br>Internet users (population)=%{x}<br>Offline population=%{y}<br>Population=%{marker.size}<extra></extra>","hovertext":["Azerbaijan"],"ids":["Azerbaijan"],"legendgroup":"Azerbaijan","marker":{"color":"#19d3f3","size":[9.7],"sizemode":"area","sizeref":0.46115702479338844,"symbol":"circle"},"mode":"markers","name":"Azerbaijan","orientation":"v","showlegend":true,"x":[7.41],"xaxis":"x","y":[2.21],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Bahrain<br>Year=2017<br>Internet users (population)=%{x}<br>Offline population=%{y}<br>Population=%{marker.size}<extra></extra>","hovertext":["Bahrain"],"ids":["Bahrain"],"legendgroup":"Bahrain","marker":{"color":"#FF6692","size":[1.4],"sizemode":"area","sizeref":0.46115702479338844,"symbol":"circle"},"mode":"markers","name":"Bahrain","orientation":"v","showlegend":true,"x":[1.28],"xaxis":"x","y":[0.09],"yaxis":"y","type":"scatter"} ...

# %%
df_3i_corrected['Mobile subscribers (Percentage)'] = df_3i_corrected['Mobile subscribers']/df_3i_corrected['Population']
df_3i_corrected['Offline population (Percentage)'] = df_3i_corrected['Offline population']/df_3i_corrected['Population'] * 100

# %% [markdown]
# ## 1. Share of population using the internet

# %%
def get_top_k(df, sort_by, k=15, ascending=False):
    # Top K after grouping inspired by 
    # https://stackoverflow.com/a/66551484

    return df.groupby('Year').apply(lambda x : x.sort_values(by = sort_by, ascending = ascending).head(k)).reset_index(drop=True)

# %%
df_3i_corrected.columns
# Out:
# Index(['Country', 'Edition', 'Fixed-line broadband subscribers',
#        'Mobile subscribers', 'Gender gap in internet access',
#        'Gender gap in mobile phone access', 'Average mobile latency',
#        'Bandwidth capacity', 'Internet exchange points',
#        'Urban electricity access', 'Rural electricity access',
#        'Smartphone cost (handset)',
#        'Average revenue per user (ARPU, annualized)', 'e-Entertainment usage',
#        'Nominal GDP', 'Population', 'Urban population', 'GNI per capita',
#        'GINI coefficient', 'Population under the poverty line',
#        'Total electricity access',
#        'Percentage of schools with Internet access', 'Global Peace Index',
#        'Democracy Index', 'Internet users (population)', 'Offline population',
#        'Internet access gender gap', 'Mobile phone access gender gap',
#        'Internet users (percent of population)', 'Male internet users',
#        'Female internet users', 'Male mobile phone subscribers',
#        'Female mobile phone subscribers',
#        'Total fixed line broadband subscribers', 'Year',
#        'Mobile subscribers (Percentage)', 'Offline population (Percentage)'],
#       dtype='object')

# %%
df_internet_users = df_3i_corrected[['Year', 'Country', 'Internet users (population)', 'Offline population', 'Internet users (percent of population)', 'Population', 'Mobile subscribers (Percentage)' ]]

df_internet_users_top_15 = get_top_k(df_internet_users, 'Internet users (population)')
df_internet_users_bottom_15 = get_top_k(df_internet_users, 'Internet users (population)', ascending=True)

df_internet_users_top_15.to_csv("df_internet_users_top_15.csv", index=False)
df_internet_users_bottom_15.to_csv("df_internet_users_bottom_15.csv", index=False)

# %%
bars = (
    alt.Chart(df_internet_users_bottom_15.query('Year == 2021'))
    .mark_bar()
    .encode(
        alt.X('Country', sort=None),
        alt.Y('Internet users (population)', 
        sort=['Internet users (population)']),
        color='Country',
    )
)
plot_title = f"Bottom 15 countries ranked by Internet Users (in millions)"
bars.properties(title=plot_title)
# Out:
# alt.Chart(...)

# %%
bars = (
    alt.Chart(df_internet_users_top_15.query('Year == 2021'))
    .mark_bar()
    .encode(
        alt.X('Country', sort=None),
        alt.Y('Internet users (population)', 
        sort=['Internet users (population)']),
        color='Country',
    )
)
plot_title = f"Top 15 countries ranked by Internet Users (in millions)"
bars.properties(title=plot_title)
# Out:
# alt.Chart(...)

# %%
df_percentage_internet_users = df_3i_corrected[['Year', 'Country', 'Internet users (population)', 'Offline population', 'Internet users (percent of population)', 'Population', 'Mobile subscribers (Percentage)' ]]

df_percentage_internet_users_top_15 = get_top_k(df_percentage_internet_users, 'Internet users (percent of population)')
df_percentage_internet_users_bottom_15 = get_top_k(df_percentage_internet_users, 'Internet users (percent of population)', ascending=True)

df_percentage_internet_users_top_15.to_csv("df_percentage_internet_users_top_15.csv", index=False)
df_percentage_internet_users_bottom_15.to_csv("df_percentage_internet_users_bottom_15.csv", index=False)

# %%
bars1 = (
    alt.Chart(df_percentage_internet_users_top_15.query('Year == 2021'))
    .mark_bar()
    .encode(
        alt.X('Country', sort=None),
        alt.Y('Internet users (percent of population)', 
        sort=['Internet users (percent of population)']),
        color='Country',
    )
)
plot_title = f"Top 15 countries ranked by Percentage of the population with Internet access"
bars1.properties(title=plot_title)

bars2 = (
    alt.Chart(df_percentage_internet_users_bottom_15.query('Year == 2021'))
    .mark_bar()
    .encode(
        x = alt.X('Country', sort=None),
        y = alt.Y('Internet users (percent of population)'),
        color='Country',
    )
)
plot_title = f"Bottom 15 countries ranked by Percentage of the population with Internet access"
bars2.properties(title=plot_title)


bars1 | bars2
alt.hconcat(bars1, bars2, title="Top (L) and Bottom (R) 15 countries ranked by Percentage of the population with Internet access")
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# Just over 20% of Europeans are offline, for example, compared with about 75% of
# people living in Africa.

# %% [markdown]
# ## 2. Number of Internet Users

# %%
df_percentage_offline_population = df_3i_corrected[['Year', 'Country', 'Internet users (population)', 'Offline population', 'Offline population (Percentage)', 'Internet users (percent of population)', 'Population', 'Mobile subscribers (Percentage)' ]]

df_percentage_offline_population_top_15 = get_top_k(df_percentage_offline_population, 'Offline population (Percentage)')
df_percentage_offline_population_bottom_15 = get_top_k(df_percentage_offline_population, 'Offline population (Percentage)', ascending=True)

df_percentage_offline_population_top_15.to_csv("df_percentage_offline_population_top_15.csv", index=False)
df_percentage_offline_population_bottom_15.to_csv("df_percentage_offline_population_bottom_15.csv", index=False)

# %%
bars1 = (
    alt.Chart(df_percentage_offline_population_top_15.query('Year == 2021'))
    .mark_bar()
    .encode(
        alt.X('Country', sort=None),
        alt.Y('Offline population (Percentage)'),
        color='Country',
    )
)
plot_title = f"Top 15 countries ranked by Percentage of the population without Internet access"
bars1.properties(title=plot_title)

bars2 = (
    alt.Chart(df_percentage_offline_population_bottom_15.query('Year == 2021'))
    .mark_bar()
    .encode(
        x = alt.X('Country', sort=None),
        y = alt.Y('Offline population (Percentage)'),
        color='Country',
    )
)
plot_title = f"Bottom 15 countries ranked by Percentage of the population without Internet access"
bars2.properties(title=plot_title)


bars1 | bars2
alt.hconcat(bars1, bars2, title="Top (L) and Bottom (R) 15 countries ranked by Percentage of the population with Internet access")
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# ## 3. Mobile phone use

# %%
df_3i_corrected['Mobile subscribers (Percentage)'] = df_3i_corrected['Mobile subscribers']/df_3i_corrected['Population']
df_3i_corrected['Mobile subscribers (Percentage)']
# Out:
# 0      2.679803
# 1      2.808717
# 2      2.631829
# 3      2.603730
# 4      2.503432
#          ...
# 595    6.592857
# 596    6.464789
# 597    6.875000
# 598    6.123288
# 599    6.046980
# Name: Mobile subscribers (Percentage), Length: 600, dtype: float64

# %%
fig = px.scatter(df_3i_corrected, x="GNI per capita", y="Mobile subscribers (Percentage)", animation_frame="Year", animation_group="Country", color="Country", hover_name="Country", 
#                  labels={
#                  "depression_rates": "Prevalence - Depressive disorders (Depression Rate) in %",
#                  "suicide_rates": "Deaths - Self-harm (Suicide Rate) in %",
#                  "population": "Population",
#                  "continent": "Continent"
#              }, 
#                  range_x=[2000, 5500], range_y=[0, 50],
           log_x=False, size_max=55, title="Mobile subscribers vs GNI. per capita")
fig.show()
# Out:
# <div>                            <div id="c0edeaa0-561c-4632-b4aa-b4ce486a3901" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c0edeaa0-561c-4632-b4aa-b4ce486a3901")) {                    Plotly.newPlot(                        "c0edeaa0-561c-4632-b4aa-b4ce486a3901",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Algeria<br>Year=2017<br>GNI per capita=%{x}<br>Mobile subscribers (Percentage)=%{y}<extra></extra>","hovertext":["Algeria"],"ids":["Algeria"],"legendgroup":"Algeria","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Algeria","orientation":"v","showlegend":true,"x":[4850],"xaxis":"x","y":[2.6798029556650245],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Angola<br>Year=2017<br>GNI per capita=%{x}<br>Mobile subscribers (Percentage)=%{y}<extra></extra>","hovertext":["Angola"],"ids":["Angola"],"legendgroup":"Angola","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Angola","orientation":"v","showlegend":true,"x":[4520],"xaxis":"x","y":[1.7291666666666665],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Argentina<br>Year=2017<br>GNI per capita=%{x}<br>Mobile subscribers (Percentage)=%{y}<extra></extra>","hovertext":["Argentina"],"ids":["Argentina"],"legendgroup":"Argentina","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Argentina","orientation":"v","showlegend":true,"x":[12570],"xaxis":"x","y":[3.301149425287356],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Australia<br>Year=2017<br>GNI per capita=%{x}<br>Mobile subscribers (Percentage)=%{y}<extra></extra>","hovertext":["Australia"],"ids":["Australia"],"legendgroup":"Australia","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Australia","orientation":"v","showlegend":true,"x":[60500],"xaxis":"x","y":[4.432098765432099],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Austria<br>Year=2017<br>GNI per capita=%{x}<br>Mobile subscribers (Percentage)=%{y}<extra></extra>","hovertext":["Austria"],"ids":["Austria"],"legendgroup":"Austria","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Austria","orientation":"v","showlegend":true,"x":[47450],"xaxis":"x","y":[18.046511627906977],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Azerbaijan<br>Year=2017<br>GNI per capita=%{x}<br>Mobile subscribers (Percentage)=%{y}<extra></extra>","hovertext":["Azerbaijan"],"ids":["Azerbaijan"],"legendgroup":"Azerbaijan","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Azerbaijan","orientation":"v","showlegend":true,"x":[6570],"xaxis":"x","y":[11.463917525773198],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Bahrain<br>Year=2017<br>GNI per capita=%{x}<br>Mobile subscribers (Percentage)=%{y}<extra></extra>","hovertext":["Bahrain"],"ids":["Bahrain"],"legendgroup":"Bahrain","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Bahrain","orientation":"v","showlegend":true,"x":[22660],"xaxis":"x","y":[131.14285714285714],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Bangladesh<br>Year=2017<br>GNI per capita=%{x}<br>Mobile subscribers (Percentage)=%{y}<extra></extra>","hovertext":["Bangladesh"],"ids":["Bangladesh"],"legendgroup":"Bangladesh","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"Bangladesh","orientation":"v","showlegend":true,"x":[1220],"xaxis":"x","y":[0.5322784810126582],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Belgium<br>Year=2017<br>GNI per capita=%{x}<br>Mobile sub ...

# %% [markdown]
# ## 4. Correlation between Internet users and GDP per capita

# %% [markdown]
# ## 5. Cost of data

# %%
df_3i_corrected.columns
# Out:
# Index(['Country', 'Edition', 'Fixed-line broadband subscribers',
#        'Mobile subscribers', 'Gender gap in internet access',
#        'Gender gap in mobile phone access', 'Average mobile latency',
#        'Bandwidth capacity', 'Internet exchange points',
#        'Urban electricity access', 'Rural electricity access',
#        'Smartphone cost (handset)',
#        'Average revenue per user (ARPU, annualized)', 'e-Entertainment usage',
#        'Nominal GDP', 'Population', 'Urban population', 'GNI per capita',
#        'GINI coefficient', 'Population under the poverty line',
#        'Total electricity access',
#        'Percentage of schools with Internet access', 'Global Peace Index',
#        'Democracy Index', 'Internet users (population)', 'Offline population',
#        'Internet access gender gap', 'Mobile phone access gender gap',
#        'Internet users (percent of population)', 'Male internet users',
#        'Female internet users', 'Male mobile phone subscribers',
#        'Female mobile phone subscribers',
#        'Total fixed line broadband subscribers', 'Year',
#        'Mobile subscribers (Percentage)', 'Offline population (Percentage)'],
#       dtype='object')

# %%
out = df_3i_corrected[['Year', 'Country', 'Internet users (population)', 'Offline population', 'Internet users (percent of population)', 'Population' ]]
out.to_csv("3i.csv", index=False)

# %%
g = out.groupby(['Year']).apply(lambda x: x.nlargest(topk, ['value'])).reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.pyenv/versions/3.8.0/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'value'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-144-9dd08e2c1cd1> in <module>
# ----> 1 g = out.groupby(['Year']).apply(lambda x: x.nlargest(topk, ['value'])).reset_index(drop=True)
#       2
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     857         with option_context("mode.chained_assignment", None):
#     858             try:
# --> 859                 result = self._python_apply_general(f, self._selected_obj)
#     860             except TypeError:
#     861                 # gh-20949
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data)
#     890             data after applying f
#     891         """
# --> 892         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#     893
#     894         return self._wrap_applied_output(
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     218             # group might be modified
#     219             group_axes = group.axes
# --> 220             res = f(group)
#     221             if not _is_indexed_like(res, group_axes):
#     222                 mutated = True
#
# <ipython-input-144-9dd08e2c1cd1> in <lambda>(x)
# ----> 1 g = out.groupby(['Year']).apply(lambda x: x.nlargest(topk, ['value'])).reset_index(drop=True)
#       2
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/site-packages/pandas/core/frame.py in nlargest(self, n, columns, keep)
#    5683         Brunei      434000    12128      BN
#    5684         """
# -> 5685         return algorithms.SelectNFrame(self, n=n, keep=keep, columns=columns).nlargest()
#    5686
#    5687     def nsmallest(self, n, columns, keep="first") -> "DataFrame":
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/site-packages/pandas/core/algorithms.py in nlargest(self)
#    1156
#    1157     def nlargest(self):
# -> 1158         return self.compute("nlargest")
#    1159
#    1160     def nsmallest(self):
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/site-packages/pandas/core/algorithms.py in compute(self, method)
#    1270
#    1271         for column in columns:
# -> 1272             dtype = frame[column].dtype
#    1273             if not self.is_valid_dtype_n_method(dtype):
#    1274                 raise TypeError(
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# ~/.pyenv/versions/3.8.0/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'value'

# %%
out
# Out:
#      Year   Country  Internet users (population)  Offline population  \
# 0    2017   Algeria                        15.23               24.64
# 1    2018   Algeria                        17.44               23.18
# 2    2019   Algeria                        19.71               21.62
# 3    2020   Algeria                        20.64               21.45
# 4    2021   Algeria                        20.64               21.45
# ..    ...       ...                          ...                 ...
# 595  2017  Zimbabwe                         3.14               10.67
# 596  2018  Zimbabwe                         3.24               10.79
# 597  2019  Zimbabwe                         3.85               10.39
# 598  2020  Zimbabwe                         3.85               10.39
# 599  2021  Zimbabwe                         3.85               10.39
#
#      Internet users (percent of population)  Population
# 0                                      38.2        40.6
# 1                                      42.9        41.3
# 2                                      47.7        42.1
# 3                                      49.0        42.9
# 4                                      49.0        43.7
# ..                                      ...         ...
# 595                                    22.7        14.0
# 596                                    23.1        14.2
# 597                                    27.1        14.4
# 598                                    27.1        14.6
# 599                                    27.1        14.9
#
# [600 rows x 6 columns]

# %%
# Top K after grouping inspired by 
# https://stackoverflow.com/a/66551484

topk = 15
sort_by = 'Offline population'
out2 = out.groupby('Year').apply(lambda x : x.sort_values(by = sort_by, ascending = False).head(topk)).reset_index(drop=True)

# %%
out2.to_csv("3i_out.csv", index=False)

# %%
from IPython.display import IFrame
IFrame(src='https://flo.uri.sh/story/1056561/embed', width=700, height=600)
# <iframe src='<iframe src='https://flo.uri.sh/story/1056561/embed' title='Interactive or visual content' class='flourish-embed-iframe' frameborder='0' scrolling='no' style='width:100%;height:600px;' sandbox='allow-same-origin allow-forms allow-scripts allow-downloads allow-popups allow-popups-to-escape-sandbox allow-top-navigation-by-user-activation'></iframe><div style='width:100%!;margin-top:4px!important;text-align:right!important;'><a class='flourish-credit' href='https://public.flourish.studio/story/1056561/?utm_source=embed&utm_campaign=story/1056561' target='_top' style='text-decoration:none!important'><img alt='Made with Flourish' src='https://public.flourish.studio/resources/made_with_flourish.svg' style='width:105px!important;height:16px!important;border:none!important;margin:0!important;'> </a></div>' title='Interactive or visual content' class='flourish-embed-iframe' frameborder='0' scrolling='no' style='width:100%;height:600px;' sandbox='allow-same-origin allow-forms allow-scripts allow-downloads allow-popups allow-popups-to-escape-sandbox allow-top-navigation-by-user-activation'></iframe><div style='width:100%!;margin-top:4px!important;text-align:right!important;'><a class='flourish-credit' href='https://public.flourish.studio/story/1056561/?utm_source=embed&utm_campaign=story/1056561' target='_top' style='text-decoration:none!important'><img alt='Made with Flourish' src='https://public.flourish.studio/resources/made_with_flourish.svg' style='width:105px!important;height:16px!important;border:none!important;margin:0!important;'> </a></div>
# <iframe src='https://flo.uri.sh/visualisation/8015383/embed' title='Interactive or visual content' class='flourish-embed-iframe' frameborder='0' scrolling='no' style='width:100%;height:600px;' sandbox='allow-same-origin allow-forms allow-scripts allow-downloads allow-popups allow-popups-to-escape-sandbox allow-top-navigation-by-user-activation'></iframe><div style='width:100%!;margin-top:4px!important;text-align:right!important;'><a class='flourish-credit' href='https://public.flourish.studio/visualisation/8015383/?utm_source=embed&utm_campaign=visualisation/8015383' target='_top' style='text-decoration:none!important'><img alt='Made with Flourish' src='https://public.flourish.studio/resources/made_with_flourish.svg' style='width:105px!important;height:16px!important;border:none!important;margin:0!important;'> </a></div>
# Out:
#         <iframe
#             width="700"
#             height="600"
#             src="https://flo.uri.sh/story/1056561/embed"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
